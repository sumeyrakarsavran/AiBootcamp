# %% [markdown]
# # Kaggle veri seti ile ev tahmini yapan model oluşturacağız. Gradient Boosting ve Random forest regressors kullancağız.

# %% [markdown]
# Data fields
# Here's a brief version of what you'll find in the data description file.
# 1.	SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# 2.	MSSubClass: The building class
# 3.	MSZoning: The general zoning classification
# 4.	LotFrontage: Linear feet of street connected to property
# 5.	LotArea: Lot size in square feet
# 6.	Street: Type of road access
# 7.	Alley: Type of alley access
# 8.	LotShape: General shape of property
# 9.	LandContour: Flatness of the property
# 10.	Utilities: Type of utilities available
# 11.	LotConfig: Lot configuration
# 12.	LandSlope: Slope of property
# 13.	Neighborhood: Physical locations within Ames city limits
# 14.	Condition1: Proximity to main road or railroad
# 15.	Condition2: Proximity to main road or railroad (if a second is present)
# 16.	BldgType: Type of dwelling
# 17.	HouseStyle: Style of dwelling
# 18.	OverallQual: Overall material and finish quality
# 19.	OverallCond: Overall condition rating
# 20.	YearBuilt: Original construction date
# 21.	YearRemodAdd: Remodel date
# 22.	RoofStyle: Type of roof
# 23.	RoofMatl: Roof material
# 24.	Exterior1st: Exterior covering on house
# 25.	Exterior2nd: Exterior covering on house (if more than one material)
# 26.	MasVnrType: Masonry veneer type
# 27.	MasVnrArea: Masonry veneer area in square feet
# 28.	ExterQual: Exterior material quality
# 29.	ExterCond: Present condition of the material on the exterior
# 30.	Foundation: Type of foundation
# 31.	BsmtQual: Height of the basement
# 32.	BsmtCond: General condition of the basement
# 33.	BsmtExposure: Walkout or garden level basement walls
# 34.	BsmtFinType1: Quality of basement finished area
# 35.	BsmtFinSF1: Type 1 finished square feet
# 36.	BsmtFinType2: Quality of second finished area (if present)
# 37.	BsmtFinSF2: Type 2 finished square feet
# 38.	BsmtUnfSF: Unfinished square feet of basement area
# 39.	TotalBsmtSF: Total square feet of basement area
# 40.	Heating: Type of heating
# 41.	HeatingQC: Heating quality and condition
# 42.	CentralAir: Central air conditioning
# 43.	Electrical: Electrical system
# 44.	1stFlrSF: First Floor square feet
# 45.	2ndFlrSF: Second floor square feet
# 46.	LowQualFinSF: Low quality finished square feet (all floors)
# 47.	GrLivArea: Above grade (ground) living area square feet
# 48.	BsmtFullBath: Basement full bathrooms
# 49.	BsmtHalfBath: Basement half bathrooms
# 50.	FullBath: Full bathrooms above grade
# 51.	HalfBath: Half baths above grade
# 52.	Bedroom: Number of bedrooms above basement level
# 53.	Kitchen: Number of kitchens
# 54.	KitchenQual: Kitchen quality
# 55.	TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# 56.	Functional: Home functionality rating
# 57.	Fireplaces: Number of fireplaces
# 58.	FireplaceQu: Fireplace quality
# 59.	GarageType: Garage location
# 60.	GarageYrBlt: Year garage was built
# 61.	GarageFinish: Interior finish of the garage
# 62.	GarageCars: Size of garage in car capacity
# 63.	GarageArea: Size of garage in square feet
# 64.	GarageQual: Garage quality
# 65.	GarageCond: Garage condition
# 66.	PavedDrive: Paved driveway
# 67.	WoodDeckSF: Wood deck area in square feet
# 68.	OpenPorchSF: Open porch area in square feet
# 69.	EnclosedPorch: Enclosed porch area in square feet
# 70.	3SsnPorch: Three season porch area in square feet
# 71.	ScreenPorch: Screen porch area in square feet
# 72.	PoolArea: Pool area in square feet
# 73.	PoolQC: Pool quality
# 74.	Fence: Fence quality
# 75.	MiscFeature: Miscellaneous feature not covered in other categories
# 76.	MiscVal: $Value of miscellaneous feature
# 77.	MoSold: Month Sold
# 78.	YrSold: Year Sold
# 79.	SaleType: Type of sale
# 80.	SaleCondition: Condition of sale

# %% [markdown]
# Veri alanları
# İşte veri açıklama dosyasında bulacağınız şeylerin kısa bir versiyonu.
# 1. SalePrice - mülkün dolar cinsinden satış fiyatı. Bu, tahmin etmeye çalıştığınız hedef değişkendir.
# 2. MSSubClass: Bina sınıfı
# 3. MSZoning: Genel imar sınıflandırması
# 4. LotFrontage: Mülke bağlı sokağın doğrusal ayakları
# 5. LotArea: Metrekare cinsinden arsa büyüklüğü
# 6. Street: Yol erişim türü
# 7. Alley: Sokak erişim türü
# 8. LotShape: Mülkün genel şekli
# 9. LandContour: Mülkün düzlüğü
# 10. Utilities: Mevcut kamu hizmetleri türü
# 11. LotConfig: Lot konfigürasyonu
# 12. LandSlope: Mülkün eğimi
# 13. Neighborhood: Ames şehir sınırları içindeki fiziksel konumlar
# 14. Condition1: Ana yola veya demir yoluna yakınlık
# 15. Condition2: Ana yola veya demir yoluna yakınlık (ikincisi varsa)
# 16. BldgType: Konut türü
# 17. HouseStyle: Konut tarzı
# 18. OverallQual: Genel malzeme ve bitiş kalitesi
# 19. OverallCond: Genel durum derecelendirme
# 20. YılYapım: Orijinal inşaat tarihi
# 21. YılYenilemeEkleme: Yenileme tarihi
# 22. ÇatıStil: Çatı tipi
# 23. ÇatıMalzemesi: Çatı malzemesi
# 24. Dış1.: Evin dış kaplaması
# 25. Dış2.: Evin dış kaplaması (birden fazla malzeme varsa)
# 26. MasVnrType: Duvar kaplaması tipi
# 27. MasVnrAlan: Duvar kaplaması alanı (metrekare cinsinden)
# 28. ExterQual: Dış malzeme kalitesi
# 29. ExterCond: Dıştaki malzemenin mevcut durumu
# 30. Temel: Temel tipi
# 31. BsmtQual: Bodrumun yüksekliği
# 32. BsmtCond: Bodrumun genel durumu
# 33. BsmtExposure: Çıkıntılı veya bahçe seviyesindeki bodrum duvarları
# 34. BsmtFinType1: Bodrumun bitmiş alanının kalitesi
# 35. BsmtFinSF1: Tip 1 bitmiş kare feet
# 36. BsmtFinType2: İkinci bitmiş alanın kalitesi (varsa)
# 37. BsmtFinSF2: Tip 2 bitmiş kare feet
# 38. BsmtUnfSF: Bodrum katı alanının tamamlanmamış kare feet'i
# 39. TotalBsmtSF: Bodrum katı alanının toplam kare feet'i
# 40. Isıtma: Isıtma türü
# 41. HeatingQC: Isıtma kalitesi ve durumu
# 42. CentralAir: Merkezi klima
# 43. Elektrik: Elektrik sistemi
# 44. 1stFlrSF: Birinci kat kare feet
# 45. 2ndFlrSF: İkinci kat kare feet
# 46. LowQualFinSF: Düşük kaliteli bitmiş kare feet (tüm katlar)
# 47. GrLivArea: Zemin üstü (zemin) yaşam alanı kare feet
# 48. BsmtFullBath: Bodrum katı tam banyolar
# 49. BsmtHalfBath: Bodrum katı yarım banyolar
# 50. FullBath: Zemin üstü tam banyolar
# 51. HalfBath: Zemin üstünde yarım banyo
# 52. Yatak odası: Bodrum katının üstündeki yatak odası sayısı
# 53. Mutfak: Mutfak sayısı
# 54. KitchenQual: Mutfak kalitesi
# 55. TotRmsAbvGrd: Zemin üstündeki toplam oda sayısı (banyolar dahil değildir)
# 56. Functional: Ev işlevsellik derecesi
# 57. Şömineler: Şömine sayısı
# 58. FireplaceQu: Şömine kalitesi
# 59. GarageType: Garaj konumu
# 60. GarageYrBlt: Garajın inşa edildiği yıl
# 61. GarageFinish: Garajın iç kaplaması
# 62. GarageCars: Garajın araç kapasitesine göre boyutu
# 63. GarageArea: Garajın metrekare cinsinden boyutu
# 64. GarageQual: Garaj kalitesi
# 65. GarageCond: Garaj durumu
# 66. PavedDrive: Asfaltlı araba yolu
# 67. WoodDeckSF: Ahşap güverte alanı metrekare cinsinden
# 68. OpenPorchSF: Açık veranda alanı metrekare cinsinden
# 69. EnclosedPorch: Kapalı veranda alanı (metrekare)
# 70. 3SsnPorch: Üç mevsim veranda alanı (metrekare)
# 71. ScreenPorch: Ekran veranda alanı (metrekare)
# 72. PoolArea: Havuz alanı (metrekare)
# 73. PoolQC: Havuz kalitesi
# 74. Fence: Çit kalitesi
# 75. MiscFeature: Diğer kategorilerde yer almayan çeşitli özellikler
# 76. MiscVal: Çeşitli özelliklerin $Value'si
# 77. MoSold: Satış Ayı
# 78. YrSold: Satış Yılı
# 79. SaleType: Satış türü
# 80. SaleCondition: Satış durumu

# %%
import pandas as pd

# %%
df1=pd.read_csv('train.csv')
df2=pd.read_csv('test.csv')
df=pd.concat([df1,df2],ignore_index=True)

# %%
df1.shape
# Out:
# (1460, 81)

# %%
df2.shape
# Out:
# (1459, 80)

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 2914         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2915         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2916         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2917         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 2918         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df[['YearBuilt','YearRemodAdd','GarageYrBlt','YrSold']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0       2003          2003       2003.0    2008
# 1       1976          1976       1976.0    2007
# 2       2001          2002       2001.0    2008
# 3       1915          1970       1998.0    2006
# 4       2000          2000       2000.0    2008

# %%
tarih_sütunları=['YearBuilt','YearRemodAdd','GarageYrBlt','YrSold']
for column in tarih_sütunları:
    df[column]=2024-df[column]

# %%
df[['YearBuilt','YearRemodAdd','GarageYrBlt','YrSold']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0         21            21         21.0      16
# 1         48            48         48.0      17
# 2         23            22         23.0      16
# 3        109            54         26.0      18
# 4         24            24         24.0      16

# %%
for column in df.columns:
    print(column,":",df[column].isnull().sum())
# Out:
# Id : 0
# MSSubClass : 0
# MSZoning : 4
# LotFrontage : 486
# LotArea : 0
# Street : 0
# Alley : 2721
# LotShape : 0
# LandContour : 0
# Utilities : 2
# LotConfig : 0
# LandSlope : 0
# Neighborhood : 0
# Condition1 : 0
# Condition2 : 0
# BldgType : 0
# HouseStyle : 0
# OverallQual : 0
# OverallCond : 0
# YearBuilt : 0
# YearRemodAdd : 0
# RoofStyle : 0
# RoofMatl : 0
# Exterior1st : 1
# Exterior2nd : 1
# MasVnrType : 1766
# MasVnrArea : 23
# ExterQual : 0
# ExterCond : 0
# Foundation : 0
# BsmtQual : 81
# BsmtCond : 82
# BsmtExposure : 82
# BsmtFinType1 : 79
# BsmtFinSF1 : 1
# BsmtFinType2 : 80
# BsmtFinSF2 : 1
# BsmtUnfSF : 1
# TotalBsmtSF : 1
# Heating : 0
# HeatingQC : 0
# CentralAir : 0
# Electrical : 1
# 1stFlrSF : 0
# 2ndFlrSF : 0
# LowQualFinSF : 0
# GrLivArea : 0
# BsmtFullBath : 2
# BsmtHalfBath : 2
# FullBath : 0
# HalfBath : 0
# BedroomAbvGr : 0
# KitchenAbvGr : 0
# KitchenQual : 1
# TotRmsAbvGrd : 0
# Functional : 2
# Fireplaces : 0
# FireplaceQu : 1420
# GarageType : 157
# ...

# %%
import seaborn as sns
sns.boxplot(x=df['SalePrice'])
# Out:
# <Axes: xlabel='SalePrice'>

# %%
# %30dan fazlası boş olanları sil
threshold = 0.3 * len(df)
columns_to_drop = df.columns[df.isnull().sum() > threshold]

print("Silinen sütunlar:", columns_to_drop.tolist())
# Out:
# Silinen sütunlar: ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature', 'SalePrice']

# %%
abs(df.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False))
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# YrSold           0.028923
# BsmtFinSF2       0.011378
# BsmtHalfBath     0.016844
# MiscVal          0.021190
# Id               0.021917
# LowQualFinSF     0.025606
# OverallCond      0.077856
# MSSubClass       0.084284
# EnclosedPorch    0.128578
# KitchenAbvGr     0.135907
# ...

# %%
columns = ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature', 'SalePrice']
selected_df = df[columns]
selected_df = pd.get_dummies(selected_df, drop_first=True)
abs(selected_df.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False))
# Out:
# SalePrice             1.000000
# FireplaceQu_Gd        0.339329
# MasVnrType_Stone      0.330476
# MasVnrType_BrkFace    0.198191
# FireplaceQu_TA        0.163147
# MiscFeature_TenC      0.022773
# PoolQC_Fa             0.016127
# PoolQC_Gd             0.012038
# FireplaceQu_Fa        0.026086
# Alley_Pave            0.027655
# MiscFeature_Othr      0.040538
# Fence_MnWw            0.051164
# MiscFeature_Shed      0.069771
# FireplaceQu_Po        0.075916
# Fence_GdWo            0.100047
# Fence_MnPrv           0.140613
# Name: SalePrice, dtype: float64

# %%
df = df.drop(['Alley', 'PoolQC', 'MiscFeature'], axis=1)

# %%
#bazı sütunları 0 ile dolduralım
columns0=['GarageArea','GarageYrBlt','GarageCars']
df[columns0]=df[columns0].fillna(0)

# %%
df=df.fillna(df.mode().iloc[0])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Id             0
# HalfBath       0
# FireplaceQu    0
# Fireplaces     0
# Functional     0
#               ..
# MasVnrArea     0
# MasVnrType     0
# Exterior2nd    0
# Exterior1st    0
# SalePrice      0
# Length: 78, dtype: int64

# %%
sorted_correlation= df.corr(numeric_only=True)['SalePrice'].abs().sort_values(ascending=False)

# %%
filtered_correlation = sorted_correlation[sorted_correlation > 0.1]

# %%
filtered_correlation
# Out:
# SalePrice       1.000000
# OverallQual     0.517966
# GrLivArea       0.498832
# GarageCars      0.417674
# GarageArea      0.411303
# TotalBsmtSF     0.410094
# 1stFlrSF        0.399258
# TotRmsAbvGrd    0.381723
# FullBath        0.369301
# YearBuilt       0.345886
# YearRemodAdd    0.342756
# MasVnrArea      0.320592
# Fireplaces      0.317945
# Id              0.303717
# BsmtFinSF1      0.258792
# LotArea         0.236985
# LotFrontage     0.234569
# 2ndFlrSF        0.224432
# GarageYrBlt     0.222514
# WoodDeckSF      0.214962
# OpenPorchSF     0.201566
# HalfBath        0.190542
# BsmtUnfSF       0.148425
# BsmtFullBath    0.146462
# BedroomAbvGr    0.113406
# Name: SalePrice, dtype: float64

# %%
df= df[filtered_correlation.index].copy()

# %%
df.shape
# Out:
# (2919, 25)

# %%
df.head()
# Out:
#    SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0   208500.0            7       1710         2.0       548.0        856.0
# 1   181500.0            6       1262         2.0       460.0       1262.0
# 2   223500.0            7       1786         2.0       608.0        920.0
# 3   140000.0            7       1717         3.0       642.0        756.0
# 4   250000.0            8       2198         3.0       836.0       1145.0
#
#    1stFlrSF  TotRmsAbvGrd  FullBath  YearBuilt  ...  LotArea  LotFrontage  \
# 0       856             8         2         21  ...     8450         65.0
# 1      1262             6         2         48  ...     9600         80.0
# 2       920             6         2         23  ...    11250         68.0
# 3       961             7         1        109  ...     9550         60.0
# 4      1145             9         2         24  ...    14260         84.0
#
#    2ndFlrSF  GarageYrBlt  WoodDeckSF  OpenPorchSF  HalfBath  BsmtUnfSF  \
# ...

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
train=df[:1460]
test=df[1460:]

# %%
x=train.drop('SalePrice',axis=1)
y=train['SalePrice']

# %% [markdown]
# # ML

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
r=RandomForestClassifier()
gr= GradientBoostingClassifier()

# %%
test
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 1460   140000.0            5        896         1.0       730.0        882.0
# 1461   140000.0            6       1329         1.0       312.0       1329.0
# 1462   140000.0            5       1629         2.0       482.0        928.0
# 1463   140000.0            6       1604         2.0       470.0        926.0
# 1464   140000.0            8       1280         2.0       506.0       1280.0
# ...         ...          ...        ...         ...         ...          ...
# 2914   140000.0            4       1092         0.0         0.0        546.0
# 2915   140000.0            4       1092         1.0       286.0        546.0
# 2916   140000.0            5       1224         2.0       576.0       1224.0
# 2917   140000.0            5        970         0.0         0.0        912.0
# 2918   140000.0            7       2000         3.0       650.0        996.0
#
# ...

# %%
test1=test.drop('SalePrice' ,axis=1)

# %%
test1
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 1460            5        896         1.0       730.0        882.0       896
# 1461            6       1329         1.0       312.0       1329.0      1329
# 1462            5       1629         2.0       482.0        928.0       928
# 1463            6       1604         2.0       470.0        926.0       926
# 1464            8       1280         2.0       506.0       1280.0      1280
# ...           ...        ...         ...         ...          ...       ...
# 2914            4       1092         0.0         0.0        546.0       546
# 2915            4       1092         1.0       286.0        546.0       546
# 2916            5       1224         2.0       576.0       1224.0      1224
# 2917            5        970         0.0         0.0        912.0       970
# 2918            7       2000         3.0       650.0        996.0       996
#
# ...

# %%
# Gradient Boosting

# %%
gr.fit(x,y)

# %%
tahmingr=gr.predict(test1)

# %%
tahmingr

# %%
#tahmin1 diye df oluşturduk
tahmin1=pd.DataFrame()

# %%
#id leri geri ekledik
tahmin1["Id"]=df2["Id"]

# %%
tahmin1["SalePrice"]=tahmingr

# %%
tahmin1

# %%
tahmin1.info()

# %%
tahmin1['Survived' ]=tahmin1['Survived' ].astype('int32')

# %%
tahmin1.to_csv('Titanic_tahmin1.csv',index=False)

# %%
#RandomForestClassifier

# %%
r.fit(x,y)

tahmin2=r.predict(test1)

# %%
sonuc2=pd.DataFrame()

sonuc2['Id' ]=df2['Id' ]

sonuc2['SalePrice' ]=tahmin2

# %%
sonuc2.head()

# %%
sonuc2.info()

# %%
sonuc2['SalePrice' ]=sonuc2['SalePrice' ].astype('int32')

sonuc2.to_csv('tahmin2.csv',index=False)
