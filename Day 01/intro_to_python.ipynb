# %% [markdown]
# # <font color=red>Intro to Python

# %% [markdown]
# python and pandas

# %% [markdown]
# $ \int_a^b \frac{dx}{sinx} \Sigma \Delta$

# %% [markdown]
# ### Değişken Tanımlama

# %% [markdown]
# ...

# %%
fiyat=[25,67,89,100,90]

# %%
def tax(x):
    return x*1.60

# %%
tax(78)
# Out:
# 124.80000000000001

# %%
#List comprehension

# %%
[tax(x) for x in fiyat]
# Out:
# [40.0, 107.2, 142.4, 160.0, 144.0]

# %%
#pandas

# %%
import pandas as pd

# %%
#pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('train.csv')

# %%
df.head() #defaultta ilk 5 satır, parantez içine sayı yazarsan o kadar sayı gösterir
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape #boyut yani satır sütün sayısı
# Out:
# (891, 12)

# %%
df.tail() #son 5 satır
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.plot() #bütün verilerin birbiriyle ilgili grafiği
# Out:
# <Axes: >

# %%
#pip install matplotlib
# Out:
# ...
#
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/be/f6/4ac7f10c1e8d51f42e320a0890ee7c8e45fb5b1178ed147f374a37900924/matplotlib-3.9.1-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/b6/b2/27c7a0d46c7dceb9083272eb314bef1ed43e5280a4197719656f866b496d/contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/70/11/7b81b12a5614b5d237ab70c38bdc268de3eb3880ce7bb1269122e0a415ea/fonttools-4.53.1-cp310-cp310-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
# ...

# %%
df.describe() #her satırın toplamı ortalaması vs vs
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr(numeric_only=True) #her satırın bir önceki satırla ilişkisi(korelasyonu)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
df[df['Age']<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df.columns=df.columns.str.upper()

# %%
df.head()
# Out:
#    PASSENGERID  SURVIVED  PCLASS  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 NAME  GENDER   AGE  SIBSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    PARCH            TICKET     FARE CABIN EMBARKED
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#dosyaları açma

# %%
pip install xlrd #excel için
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 92.2/96.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 784.5 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl #excel için
# Out:
# ...
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    -------------- ------------------------- 92.2/250.9 kB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 204.8/250.9 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel('sales-funnel.xlsx')

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
pip install lxml #xml için
# Out:
# ...
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/5b/bc/51530ee31e3ce25634ed790e38a62ffaea6507befd73b51926e19ce794f9/lxml-5.2.2-cp310-cp310-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    - -------------------------------------- 0.1/3.8 MB 819.2 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/3.8 MB 722.1 kB/s eta 0:00:06
#    - -------------------------------------- 0.2/3.8 MB 766.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.8 MB 737.3 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.8 MB 657.3 kB/s eta 0:00:06
#    -- ------------------------------------- 0.2/3.8 MB 686.8 kB/s eta 0:00:06
#    -- ------------------------------------- 0.3/3.8 MB 710.0 kB/s eta 0:00:05
# ...

# %%
df=pd.read_xml('catalog.xml')

# %%
df.head()
# Out:
#                 COMMON               BOTANICAL ZONE         LIGHT  PRICE  \
# 0            Bloodroot  Sanguinaria canadensis    4  Mostly Shady  $2.44
# 1            Columbine    Aquilegia canadensis    3  Mostly Shady  $9.37
# 2       Marsh Marigold        Caltha palustris    4  Mostly Sunny  $6.81
# 3              Cowslip        Caltha palustris    4  Mostly Shady  $9.90
# 4  Dutchman's-Breeches     Dicentra cucullaria    3  Mostly Shady  $6.44
#
#    AVAILABILITY
# 0         31599
# 1         30699
# 2         51799
# 3         30699
# 4         12099

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)')[2]

# %%
df.head()
# Out:
#   Country/Territory IMF[1][13]            World Bank[14]             \
#   Country/Territory   Forecast       Year       Estimate       Year
# 0             World  109529216       2024      100879560       2022
# 1     United States   28781083       2024       25439700       2022
# 2             China   18532633  [n 1]2024       17963171  [n 3]2022
# 3           Germany    4591100       2024        4082469       2022
# 4             Japan    4110452       2024        4256410       2022
#
#   United Nations[15]
#             Estimate       Year
# 0          100834796       2022
# 1           25744100       2022
# 2           17963170  [n 1]2022
# 3            4076923       2022
# 4            4232173       2022

# %%
df.to_excel('gdp.xlsx')

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_number_of_scientific_and_technical_journal_articles')[1]

# %%
df.head()
# Out:
#   Rank         Country Numbers of scientific publications (2020)  \
#   Rank         Country                                     Total
# 0  1.0           China                                    744042
# 1  2.0   United States                                    624554
# 2  3.0  United Kingdom                                    198500
# 3  4.0           India                                    191590
# 4  5.0         Germany                                    174524
#
#
#   Per million population
# 0                  527.0
# 1                 1875.0
# 2                 2959.0
# 3                  138.0
# 4                 2097.0

# %%
#ses robotu oluşturma / bonus bilgi

# %%
pip install gtts
# Out:
# ...
#   Obtaining dependency information for gtts from https://files.pythonhosted.org/packages/59/a8/e3434904445eacf03b857ac001755d8ffac49b4f3339d63592b4eda009dc/gTTS-2.5.1-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS

# %%
text="Bugün nasılsın? Neler yaptın merak ediyorum biraz anlatsana."

# %%
kayit=gTTS(text=text,lang='tr',slow=False)
kayit.save('robot.mp3')
