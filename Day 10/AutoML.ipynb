# %%
#pip install pycaret

# %%
#Regression örneği, kc_house olan regression dosyasıydı

# %%
from pycaret.regression import*

# %%
import pandas as pd

# %%
df=pd.read_pickle('kc_house.pkl')

# %%
setup(data=df, target='price')
# Out:
# <style type="text/css">
# #T_97db4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_97db4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97db4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_97db4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97db4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97db4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_97db4_row0_col1" class="data row0 col1" >2798</td>
#     </tr>
#     <tr>
#       <th id="T_97db4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97db4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_97db4_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_97db4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#feature eng ml vs hiçbir şey yapmaya gerek kalmadan tüm modelleri çalıştırarak en iyisini gösteriyor

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_0dd20 th {
#   text-align: left;
# }
# ...

# %%
#Classification örneği

# %%
df=pd.read_csv('pima-indians-diabetes.csv')

# %%
from pycaret.classification import*

# %%
setup(df,target='Outcome')
# Out:
# <style type="text/css">
# #T_19a09_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_19a09" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19a09_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_19a09_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19a09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19a09_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_19a09_row0_col1" class="data row0 col1" >7156</td>
#     </tr>
#     <tr>
#       <th id="T_19a09_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19a09_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_19a09_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_19a09_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_88fc6 th {
#   text-align: left;
# }
# ...

# %%
best_model=create_model('lr')
# Out:
# <style type="text/css">
# #T_d0e96_row10_col0, #T_d0e96_row10_col1, #T_d0e96_row10_col2, #T_d0e96_row10_col3, #T_d0e96_row10_col4, #T_d0e96_row10_col5, #T_d0e96_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d0e96" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0e96_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d0e96_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d0e96_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d0e96_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d0e96_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d0e96_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d0e96_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(best_model,plot='feature') #tahminde hangi sütun daha önemli

# %%
#Clustering örneği

# %%
df=pd.read_excel('cars.xls')

# %%
from pycaret.clustering import*

# %%
setup(df)
# Out:
# <style type="text/css">
# #T_b04ac_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b04ac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b04ac_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b04ac_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b04ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b04ac_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b04ac_row0_col1" class="data row0 col1" >251</td>
#     </tr>
#     <tr>
#       <th id="T_b04ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b04ac_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_b04ac_row1_col1" class="data row1 col1" >(804, 12)</td>
#     </tr>
#     <tr>
# ...

# %%
kmeans=create_model('kmeans',4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_17d23" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17d23_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_17d23_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_17d23_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_17d23_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_17d23_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_17d23_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17d23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17d23_row0_col0" class="data row0 col0" >0.4115</td>
#       <td id="T_17d23_row0_col1" class="data row0 col1" >600.9108</td>
# ...

# %%
plot_model(kmeans) #pca yaptık boyut düşürüp izdüşüm alıyo, 13 sütunu 6 sütuna indirdi
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(kmeans,plot='elbow') #kaç tane gruba ayıracaksak ona karar vermek için

# %%
plot_model(kmeans,plot='tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
