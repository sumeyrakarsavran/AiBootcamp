# %%
#pip install cvlib

# %%
#pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib
from cvlib.object_detection import draw_bbox

#80.000 nesneyi tanıyabiliyor bu paket

# %%
img=cv2.imread('cars.jpg')

# %%
plt.imshow(img)

# %%
box, label, count=cvlib.detect_common_objects(img) #yolov4, yolov3 kuruyo
# Out:
# ...
#   0% |                                                                        |
# ...
#  99% |####################################################################### |
# ...
# 100% |                                                                        |

# %%
output=draw_bbox(img,box, label, count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('car')
# Out:
# 11

# %%
label.count('person')
# Out:
# 1

# %%
img=cv2.imread('g8.jpg')

# %%
plt.imshow(img)

# %%
box, label, count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box, label, count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('person')
# Out:
# 6

# %%
img=cv2.imread('dogs.jpg')
box, label, count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box, label, count)
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
img=cv2.imread('mutfak.jpg')
box, label, count=cvlib.detect_common_objects(img)
output=draw_bbox(img, box,label, count)
plt.figure(figsize=(10,10))
plt.imshow(output)
