# %% [markdown]
# # BIG DATA

# %%
#Big data nın 1 milyon satırdan daha büyük bir veri olması lazım

# %% [markdown]
# ![image.png](attachment:41f59f50-1bb6-4711-b467-28f301d9234a.png)

# %% [markdown]
# spark, hadoopun üzerinde çalışıyor
#
# hadoop sistemini bilgisayara dahil etmişseniz bu bilgisayarlar geceleri açık kalıyor,
# dünyada geceleri açık kalan bilgisayarlara görevi dağıtıyorsun yani distribute ediyorsun
# sonra collect komutuyla hepsini geri çağırıyorsun ve çalışmaya devam edebiliyorsun

# %% [markdown]
# hadoop önceden çok popülerdi ama spark gelince popülerliği biraz düştü.
# spark hadoopdan 100 kat daha hızlı çalışıyor.
# çünkü spark ramde çalışıyor ve veri tabanlarının içinde çalışıyor.
# diğer programlama dillerinde veriyi veri tabanından select* ile çekiyorsun ve programın içinde
# veriyi analiz edip sonuca varıyorsun
# ama spark doğrudan verinin içinde çalışıyor yani programı verinin içine götürüyorsunuz

# %% [markdown]
# örneğin teleskop verilerini depolamak çok zor. jp, us gibi ülkeler hadoop sistemiyle bilgisayar
# güçlerini birleştiriyorlar. belli saatlerde belli bilgisayarlar açık oluyor. tüm veriyi paylaşıp
# sonra istenildiğinde kullanıyorlar
# örneğin meteroloji verileri için de öyle

# %% [markdown]
# dusk veya bulut bilişim gibi seçenekler de var
# server alacağına amazon bulut bilişim almak mantıklı, server çökerse 5 farklı yerde
# yedeği oluyo yani sorun olmuyor

# %% [markdown]
# pandasta df diyorduk sparkta artık rdd diyeceğiz
# rdd = resilient distributed dataset (dayanıklı/kendini çabuk toparlayan dağıtılmış veri seti)

# %% [markdown]
# ![image.png](attachment:40ab907e-095b-4009-95ff-686ce99f9d10.png)
